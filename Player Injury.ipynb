# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
data = pd.read_csv('injury_data.csv')

# %%
print(data.to_string())
# Out:
#      Player_Age  Player_Weight  Player_Height  Previous_Injuries  Training_Intensity  Recovery_Time  Likelihood_of_Injury
# 0            24      66.251933     175.732429                  1            0.457929              5                     0
# 1            37      70.996271     174.581650                  0            0.226522              6                     1
# 2            32      80.093781     186.329618                  0            0.613970              2                     1
# 3            28      87.473271     175.504240                  1            0.252858              4                     1
# 4            25      84.659220     190.175012                  0            0.577632              1                     1
# 5            38      75.820549     206.631824                  1            0.359209              4                     0
# 6            24      70.126050     177.044588                  0            0.823552              2                     0
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Player_Age            1000 non-null   int64
#  1   Player_Weight         1000 non-null   float64
#  2   Player_Height         1000 non-null   float64
#  3   Previous_Injuries     1000 non-null   int64
#  4   Training_Intensity    1000 non-null   float64
#  5   Recovery_Time         1000 non-null   int64
#  6   Likelihood_of_Injury  1000 non-null   int64
# dtypes: float64(3), int64(4)
# memory usage: 54.8 KB
# None

# %%
print(data.describe())
# Out:
#         Player_Age  Player_Weight  Player_Height  Previous_Injuries  \
# count  1000.000000    1000.000000    1000.000000        1000.000000
# mean     28.231000      74.794351     179.750948           0.515000
# std       6.538378       9.892621       9.888921           0.500025
# min      18.000000      40.191912     145.285701           0.000000
# 25%      22.000000      67.944028     173.036976           0.000000
# 50%      28.000000      75.020569     180.034436           1.000000
# 75%      34.000000      81.302956     186.557913           1.000000
# max      39.000000     104.650104     207.308672           1.000000
#
#        Training_Intensity  Recovery_Time  Likelihood_of_Injury
# count         1000.000000    1000.000000            1000.00000
# mean             0.490538       3.466000               0.50000
# std              0.286184       1.701099               0.50025
# min              0.000031       1.000000               0.00000
# ...

# %%
data.corr()
# Out:
#                       Player_Age  Player_Weight  Player_Height  \
# Player_Age              1.000000      -0.040288       0.044957
# Player_Weight          -0.040288       1.000000       0.030543
# Player_Height           0.044957       0.030543       1.000000
# Previous_Injuries      -0.045610       0.034290       0.008383
# Training_Intensity      0.041000       0.044447       0.048253
# Recovery_Time          -0.037407      -0.060806       0.029176
# Likelihood_of_Injury    0.000153       0.001843       0.029639
#
#                       Previous_Injuries  Training_Intensity  Recovery_Time  \
# Player_Age                    -0.045610            0.041000      -0.037407
# Player_Weight                  0.034290            0.044447      -0.060806
# Player_Height                  0.008383            0.048253       0.029176
# Previous_Injuries              1.000000           -0.021320      -0.005872
# Training_Intensity            -0.021320            1.000000      -0.038755
# ...
